# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("/Users/ayaxdiaz/Desktop/uscities.csv")

# %%
data
# Out:
#                    STATE  ID
# 0               New York  NY
# 1             California  CA
# 2               Illinois  IL
# 3                Florida  FL
# 4                  Texas  TX
# 5           Pennsylvania  PA
# 6                Georgia  GA
# 7   District of Columbia  DC
# 8          Massachusetts  MA
# 9                Arizona  AZ
# 10            Washington  WA
# 11              Michigan  MI
# 12             Minnesota  MN
# 13              Colorado  CO
# 14              Maryland  MD
# 15                Nevada  NV
# 16                Oregon  OR
# 17              Missouri  MO
# 18                  Ohio  OH
# 19               Indiana  IN
# 20        North Carolina  NC
# 21              Virginia  VA
# 22             Wisconsin  WI
# 23          Rhode Island  RI
# 24                  Utah  UT
# 25             Tennessee  TN
# 26             Louisiana  LA
# 27              Kentucky  KY
# 28              Oklahoma  OK
# 29           Connecticut  CT
# 30              Nebraska  NE
# ...

# %%
L_Data = data.STATE.str.lower()

# %%
L_Data
# Out:
# 0                 new york
# 1               california
# 2                 illinois
# 3                  florida
# 4                    texas
# 5             pennsylvania
# 6                  georgia
# 7     district of columbia
# 8            massachusetts
# 9                  arizona
# 10              washington
# 11                michigan
# 12               minnesota
# 13                colorado
# 14                maryland
# 15                  nevada
# 16                  oregon
# 17                missouri
# 18                    ohio
# 19                 indiana
# 20          north carolina
# 21                virginia
# 22               wisconsin
# 23            rhode island
# 24                    utah
# 25               tennessee
# 26               louisiana
# 27                kentucky
# 28                oklahoma
# 29             connecticut
# 30                nebraska
# 31                  hawaii
# 32              new mexico
# 33                 alabama
# ...

# %%
U_Data = data.STATE.str.upper()

# %%
U_Data
# Out:
# 0                 NEW YORK
# 1               CALIFORNIA
# 2                 ILLINOIS
# 3                  FLORIDA
# 4                    TEXAS
# 5             PENNSYLVANIA
# 6                  GEORGIA
# 7     DISTRICT OF COLUMBIA
# 8            MASSACHUSETTS
# 9                  ARIZONA
# 10              WASHINGTON
# 11                MICHIGAN
# 12               MINNESOTA
# 13                COLORADO
# 14                MARYLAND
# 15                  NEVADA
# 16                  OREGON
# 17                MISSOURI
# 18                    OHIO
# 19                 INDIANA
# 20          NORTH CAROLINA
# 21                VIRGINIA
# 22               WISCONSIN
# 23            RHODE ISLAND
# 24                    UTAH
# 25               TENNESSEE
# 26               LOUISIANA
# 27                KENTUCKY
# 28                OKLAHOMA
# 29             CONNECTICUT
# 30                NEBRASKA
# 31                  HAWAII
# 32              NEW MEXICO
# 33                 ALABAMA
# ...

# %%
L_Data.to_csv("/Users/ayaxdiaz/Desktop/L_Data.csv")

# %%
U_Data.to_csv("/Users/ayaxdiaz/Desktop/U_Data.csv")
